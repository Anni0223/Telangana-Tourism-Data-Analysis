# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina', quality=100)
# Out:
# C:\Users\91938\AppData\Local\Temp/ipykernel_1476/1494511002.py:2: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('retina', quality=100)

# %%
district_details = pd.read_excel('Demographics and facilities raw.xlsx')

# %%
district_details
# Out:
#                    District District Acronym  Population (2011)  Area (km²)  \
# 0                  Adilabad              Adi             708972        4153
# 1      Bhadradri Kothagudem              Bha            1069261        7483
# 2                 Hyderabad              Hyd            3943323         217
# 3                  Jagitial              Jag             985417        2419
# 4                   Jangaon              Jan             566376        2188
# 5   Jayashankar Bhupalpally              Jay             416763        2293
# 6          Jogulamba Gadwal              Jog             609990        2928
# 7                 Kamareddy              Kam             972625        3652
# 8                Karimnagar              Kar            1005711        2128
# 9                   Khammam              Kha            1401639        4361
# 10            Komaram Bheem              Kom             515812        4878
# 11              Mahabubabad            Mah.D             774549        2877
# 12             Mahabubnagar            Mah.R             919903        2738
# 13               Mancherial              Man             807037        4016
# 14                    Medak            Med.K             767428        2786
# 15       Medchal–Malkajgiri            Med.L            2440073        1084
# 16                   Mulugu              Mul             257744        3881
# 17             Nagarkurnool              Nag             893308        6545
# 18               Narayanpet              Nar             566874        2336
# 19                 Nalgonda              Nal            1618416        7122
# 20                   Nirmal              Nir             709418        3845
# 21                Nizamabad              Niz            1571022        4288
# 22               Peddapalli              Ped             795332        2236
# 23         Rajanna Sircilla              Raj             552037        2019
# 24              Ranga Reddy              Ran            2446265        5031
# 25               Sangareddy              San            1527628        4403
# 26                 Siddipet              Sid            1012065        3632
# 27                 Suryapet              Sur            1099560        3607
# 28                Vikarabad              Vik             927140        3386
# 29               Wanaparthy              Wan             577758        2152
# 30           Warangal Rural            War.R             718537        2175
# 31           Warangal Urban            War.U            1080858        1309
# 32      Yadadri Bhuvanagiri              Yad             739448        3092
#
#     Density  State Highways   Major District Roads  Rural Roads  \
# 0       171             80.0                 123.0        301.0
# 1       143            104.0                 410.0        420.0
# 2     18172             37.0                   5.0         77.0
# 3       407              0.0                 222.0        461.0
# 4       259             28.0                 564.0         49.0
# 5       180             33.0                 229.0        316.0
# 6       208            166.0                 280.0          0.0
# 7       266            145.0                 422.0        343.0
# 8       473             58.0                 489.0        264.0
# 9       321            185.0                 185.0        914.0
# 10      106             80.0                 652.0        297.0
# 11      269             61.0                 509.0          0.0
# 12      340            143.0                 487.0        323.0
# 13      201            111.0                 719.0        106.0
# 14      275            188.0                 374.0        245.0
# 15     2251             18.0                 152.0          0.0
# 16       66              NaN                   NaN          NaN
# 17      142            146.0                 643.0        346.0
# 18      240              NaN                   NaN          NaN
# 19      227            267.0                 186.0        542.0
# 20      185            119.0                 781.0        234.0
# 21      366             89.0                 598.0        590.0
# 22      356             12.0                 189.0        255.0
# 23      273             71.0                 314.0        341.0
# 24      486            162.0                 472.0        391.0
# 25      347             90.0                 323.0        418.0
# 26      279             99.0                 898.0        657.0
# 27      305             80.0                 594.0        359.0
# 28      274            119.0                 392.0        284.0
# 29      268             26.0                 452.0        102.0
# 30      330              9.0                 215.0         62.0
# 31      826              0.0                 697.0        164.0
# 32      239             42.0                 487.0        378.0
#
#     Four Lane Roads  Double Lane Roads  ...  \
# 0               6.0              107.0  ...
# 1             101.0              412.0  ...
# 2               0.0              119.0  ...
# 3               0.0               93.0  ...
# 4               2.0              149.0  ...
# 5               4.0              108.0  ...
# 6              10.0              181.0  ...
# 7              12.0              250.0  ...
# 8              14.0              267.0  ...
# 9              49.0              265.0  ...
# 10             12.0              412.0  ...
# 11              4.0              303.0  ...
# 12             14.0              451.0  ...
# 13             18.0              315.0  ...
# 14             17.0              268.0  ...
# 15             33.0               80.0  ...
# 16              NaN                NaN  ...
# 17             10.0              335.0  ...
# 18              NaN                NaN  ...
# 19             99.0              271.0  ...
# 20             10.0              424.0  ...
# 21             56.0              406.0  ...
# 22              4.0               57.0  ...
# 23             18.0              155.0  ...
# 24             42.0              306.0  ...
# 25              9.0              185.0  ...
# 26             37.0              347.0  ...
# 27             13.0              295.0  ...
# 28             13.0              241.0  ...
# 29              5.0              157.0  ...
# 30              2.0               41.0  ...
# 31             24.0              213.0  ...
# 32             11.0              325.0  ...
#
#     Habitations not having all weather roads     TSTDC Units  Tourist Spots  \
# 0                                         478.0          0.0           23.0
# 1                                         343.0          2.0            8.0
# 2                                           0.0          9.0           47.0
# 3                                          37.0          2.0            9.0
# 4                                         210.0          0.0           11.0
# 5                                         147.0          5.0           16.0
# 6                                          42.0          3.0           11.0
# 7                                         148.0          0.0           13.0
# 8                                          62.0          1.0           17.0
# 9                                          68.0          0.0           14.0
# 10                                        486.0          0.0           15.0
# 11                                        474.0          0.0            7.0
# 12                                        450.0          1.0           12.0
# 13                                        120.0          0.0           11.0
# 14                                        197.0          3.0           11.0
# 15                                          3.0          1.0           13.0
# 16                                          NaN          NaN            NaN
# 17                                        224.0          3.0           16.0
# 18                                          NaN          NaN            NaN
# 19                                        246.0          3.0           21.0
# 20                                         99.0          4.0           22.0
# 21                                         98.0          1.0           18.0
# 22                                         32.0          0.0            8.0
# 23                                         35.0          1.0           10.0
# 24                                        241.0          0.0           25.0
# 25                                        129.0          2.0           18.0
# 26                                        143.0          3.0           11.0
# 27                                        174.0          0.0           23.0
# 28                                        264.0          1.0           17.0
# 29                                        116.0          0.0            8.0
# 30                                        243.0          0.0            6.0
# 31                                         39.0          2.0           11.0
# 32                                        186.0          2.0           12.0
#
#     TSS Artists   Police Stations  Shops  Health Facilities   2019 DV  \
# 0           14.0             24.0    356                184    775895
# 1            8.0             31.0    443                315  12817737
# 2           56.0             87.0    700                308  13802362
# 3            9.0             19.0    592                203   3086115
# 4           11.0             15.0    335                142    328890
# 5           17.0             22.0    277                121    662530
# 6            7.0             14.0    334                123   2007995
# 7           10.0             23.0    578                237       534
# 8           42.0             20.0    563                195     77491
# 9           17.0             29.0    745                303   1413440
# 10          14.0             19.0    308                151     19189
# 11          21.0             19.0    556                218    152885
# 12          14.0             30.0    506                166   2534815
# 13          18.0             24.0    423                175    269810
# 14           8.0             21.0    520                212   5452570
# 15          14.0             23.0    782                250         0
# 16           NaN              NaN    222                119   1819800
# 17          13.0             22.0    558                245   2093312
# 18           NaN              NaN    991                116    140918
# 19          24.0             40.0    300                359    389250
# 20           7.0             21.0    412                151   3816778
# 21          16.0             35.0    759                317     46333
# 22          25.0             19.0    413                154     16581
# 23          17.0             13.0    345                124  16832897
# 24           8.0             50.0    974                415         0
# 25           8.0             34.0    846                347   4553160
# 26          45.0             26.0    684                265   2987864
# 27          13.0             27.0    735                220         0
# 28           7.0             23.0    588                223         0
# 29           7.0             15.0    324                132    298639
# 30          37.0             15.0    509                163    353500
# 31          28.0             18.0    418                156   1795230
# 32          15.0             21.0    515                192   4489374
#
#           Cagr  Total DV
# 0   -46.530464   7321575
# 1   143.387524  21600962
# 2   -16.128976  83900960
# 3    70.460384  11303514
# 4   100.737155    826280
# 5    39.624509  19632865
# 6    56.546259   6813340
# 7    61.403338      1773
# 8   -79.629550   9462383
# 9   -34.391989   9378315
# 10  -27.802925     92734
# 11    2.977785    600697
# 12  -32.670360  17180118
# 13  225.799714    867242
# 14   16.334330  20542639
# 15    0.000000         0
# 16    0.000000   1819800
# 17   52.651991   7424355
# 18  -71.133488   6401933
# 19    0.000000    389250
# 20   60.880758  13315796
# 21   93.029299    116147
# 22   72.256899     56977
# 23   97.748583  41763276
# 24    0.000000         0
# 25   80.209537  10424510
# 26  102.767155   5775285
# 27    0.000000         0
# 28    0.000000         0
# 29   70.607917    890078
# 30  163.145469    819162
# 31  -58.862874  30726603
# 32   37.456018  26893080
#
# [33 rows x 26 columns]

# %%
x=district_details['2019 DV']
y=district_details['Cagr']
n=district_details['District Acronym']

# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
def millions(x, pos):
    'The two args are the value and tick position'
    return '%1.0fM' % (x * 1e-6)


formatter = FuncFormatter(millions)

# %%
fig, ax = plt.subplots(figsize=(14,9))
ax.scatter(x, y)
fig.patch.set_facecolor('#F5F5F5')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_major_formatter(formatter)

ax.set_xlabel('Domestic Visitors 2019', labelpad=15, color='#333333')
ax.set_ylabel('CAGR of Domestic Visitors', labelpad=15, color='#333333')

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]))
# Out:
# C:\Users\91938\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
x=district_details['Total DV']
y=district_details['Cagr']
n=district_details['District Acronym']
fig, ax = plt.subplots(figsize=(14,9))
ax.scatter(x, y)
fig.patch.set_facecolor('#F5F5F5')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_major_formatter(formatter)
ax.set_xlabel('Total Domestic Visitors', labelpad=15, color='#333333')
ax.set_ylabel('CAGR of Domestic Visitors', labelpad=15, color='#333333')

for i, txt in enumerate(n):
    ax.annotate(txt, (x[i], y[i]))
