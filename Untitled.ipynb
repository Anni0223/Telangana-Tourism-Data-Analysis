# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('Demographics and facilities raw.xlsx')

# %%
sns.pairplot(df)

# %%
df
# Out:
#                    District District Acronym  Population (2011)  Area (km²)  \
# 0                  Adilabad              Adi             708972        4153
# 1      Bhadradri Kothagudem              Bha            1069261        7483
# 2                 Hyderabad              Hyd            3943323         217
# 3                  Jagitial              Jag             985417        2419
# 4                   Jangaon              Jan             566376        2188
# 5   Jayashankar Bhupalpally              Jay             416763        2293
# 6          Jogulamba Gadwal              Jog             609990        2928
# 7                 Kamareddy              Kam             972625        3652
# 8                Karimnagar              Kar            1005711        2128
# 9                   Khammam              Kha            1401639        4361
# 10            Komaram Bheem              Kom             515812        4878
# ...

# %%
df['TSTDC Units'].corr(df['2019% of total'])
# Out:
# 0.5008220249186556

# %%
df['Density'].corr(df['DV CAGR'])
# Out:
# 0.10563808563035385

# %%
df.fillna(0,inplace=True)

# %%
from scipy.stats import pearsonr
corr_coefficient, p_value = pearsonr(df['TSTDC Units'],df['2019% of total'])
print('Correlation coefficient:', corr_coefficient)
print('P-value:', p_value)
# Out:
# Correlation coefficient: 0.5068578603454743
# P-value: 0.0026107828328139817

# %%
plt.scatter(df['TSTDC Units'],df['2019% of total'])
